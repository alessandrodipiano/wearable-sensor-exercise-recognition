# %%
import sys 
from pathlib import Path
sys.path.append(str(Path().resolve().parents[1]))

BASE_DIR = Path().resolve()
PROJECT_ROOT = BASE_DIR.parent   #to go un up the the root
DATA_DIR = PROJECT_ROOT / "data" 



from python.dataset_creation import df
# Out:
# subject=s1, exercise=e1, label=correct, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e1, label=fast, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e1, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e2, label=correct, unit=u4, axis=y, valleys=11
# subject=s1, exercise=e2, label=fast, unit=u4, axis=y, valleys=11
# subject=s1, exercise=e2, label=low_amplitude, unit=u4, axis=y, valleys=11
# subject=s1, exercise=e3, label=correct, unit=u2, axis=z, valleys=10
# subject=s1, exercise=e3, label=fast, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e3, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e4, label=correct, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e4, label=fast, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e4, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e5, label=correct, unit=u2, axis=x, valleys=11
# subject=s1, exercise=e5, label=fast, unit=u2, axis=x, valleys=11
# subject=s1, exercise=e5, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s1, exercise=e6, label=correct, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e6, label=fast, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e6, label=low_amplitude, unit=u2, axis=y, valleys=10
# subject=s1, exercise=e7, label=correct, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e7, label=fast, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e7, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e8, label=correct, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e8, label=fast, unit=u2, axis=y, valleys=11
# subject=s1, exercise=e8, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s2, exercise=e1, label=correct, unit=u2, axis=z, valleys=10
# subject=s2, exercise=e1, label=fast, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e1, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e2, label=correct, unit=u4, axis=y, valleys=11
# subject=s2, exercise=e2, label=fast, unit=u4, axis=y, valleys=11
# subject=s2, exercise=e2, label=low_amplitude, unit=u4, axis=y, valleys=11
# subject=s2, exercise=e3, label=correct, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e3, label=fast, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e3, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e4, label=correct, unit=u2, axis=y, valleys=11
# subject=s2, exercise=e4, label=fast, unit=u2, axis=y, valleys=11
# subject=s2, exercise=e4, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s2, exercise=e5, label=correct, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e5, label=fast, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e5, label=low_amplitude, unit=u2, axis=x, valleys=11
# subject=s2, exercise=e6, label=correct, unit=u2, axis=y, valleys=11
# subject=s2, exercise=e6, label=fast, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e6, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e7, label=correct, unit=u3, axis=y, valleys=11
# subject=s2, exercise=e7, label=fast, unit=u3, axis=y, valleys=11
# subject=s2, exercise=e7, label=low_amplitude, unit=u3, axis=y, valleys=11
# subject=s2, exercise=e8, label=correct, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e8, label=fast, unit=u2, axis=z, valleys=11
# subject=s2, exercise=e8, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e1, label=correct, unit=u2, axis=z, valleys=10
# subject=s3, exercise=e1, label=fast, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e1, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e2, label=correct, unit=u4, axis=y, valleys=11
# subject=s3, exercise=e2, label=fast, unit=u4, axis=y, valleys=11
# subject=s3, exercise=e2, label=low_amplitude, unit=u4, axis=y, valleys=11
# subject=s3, exercise=e3, label=correct, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e3, label=fast, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e3, label=low_amplitude, unit=u2, axis=x, valleys=11
# subject=s3, exercise=e4, label=correct, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e4, label=fast, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e4, label=low_amplitude, unit=u2, axis=x, valleys=10
# subject=s3, exercise=e5, label=correct, unit=u2, axis=x, valleys=11
# subject=s3, exercise=e5, label=fast, unit=u2, axis=x, valleys=11
# subject=s3, exercise=e5, label=low_amplitude, unit=u2, axis=x, valleys=11
# subject=s3, exercise=e6, label=correct, unit=u2, axis=y, valleys=11
# subject=s3, exercise=e6, label=fast, unit=u2, axis=y, valleys=11
# subject=s3, exercise=e6, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s3, exercise=e7, label=correct, unit=u3, axis=y, valleys=10
# subject=s3, exercise=e7, label=fast, unit=u3, axis=y, valleys=11
# subject=s3, exercise=e7, label=low_amplitude, unit=u3, axis=y, valleys=11
# subject=s3, exercise=e8, label=correct, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e8, label=fast, unit=u2, axis=z, valleys=11
# subject=s3, exercise=e8, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e1, label=correct, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e1, label=fast, unit=u2, axis=z, valleys=10
# subject=s4, exercise=e1, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e2, label=correct, unit=u4, axis=y, valleys=11
# subject=s4, exercise=e2, label=fast, unit=u4, axis=y, valleys=11
# subject=s4, exercise=e2, label=low_amplitude, unit=u4, axis=y, valleys=10
# subject=s4, exercise=e3, label=correct, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e3, label=fast, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e3, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e4, label=correct, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e4, label=fast, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e4, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e5, label=correct, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e5, label=fast, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e5, label=low_amplitude, unit=u2, axis=x, valleys=11
# subject=s4, exercise=e6, label=correct, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e6, label=fast, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e6, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e7, label=correct, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e7, label=fast, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e7, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s4, exercise=e8, label=correct, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e8, label=fast, unit=u2, axis=z, valleys=11
# subject=s4, exercise=e8, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e1, label=correct, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e1, label=fast, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e1, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e2, label=correct, unit=u4, axis=y, valleys=11
# subject=s5, exercise=e2, label=fast, unit=u4, axis=y, valleys=11
# subject=s5, exercise=e2, label=low_amplitude, unit=u4, axis=y, valleys=11
# subject=s5, exercise=e3, label=correct, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e3, label=fast, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e3, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e4, label=correct, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e4, label=fast, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e4, label=low_amplitude, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e5, label=correct, unit=u2, axis=x, valleys=11
# subject=s5, exercise=e5, label=fast, unit=u2, axis=z, valleys=11
# subject=s5, exercise=e5, label=low_amplitude, unit=u2, axis=x, valleys=10
# subject=s5, exercise=e6, label=correct, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e6, label=fast, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e6, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e7, label=correct, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e7, label=fast, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e7, label=low_amplitude, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e8, label=correct, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e8, label=fast, unit=u2, axis=y, valleys=11
# subject=s5, exercise=e8, label=low_amplitude, unit=u2, axis=y, valleys=11
